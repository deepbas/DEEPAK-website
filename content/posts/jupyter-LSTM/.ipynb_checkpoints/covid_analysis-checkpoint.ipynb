# %% [markdown]
# ---
# title: "Predicting covid cases with LSTM Machine Learning Model"
# date: 2020-03-20
# tags: ["data science", "machine learning", "hugo"]
# draft: false
# ---

# %%
# Import various libraries and routines needed for computation
import math 
import pandas as pd
import numpy as np
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense, Dropout
import keras.backend as K
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from datetime import date, timedelta, datetime

# %%
df = pd.read_csv('covid_final.csv')  
dataset = df.set_index(['date'])
dataset.drop(dataset.tail(10).index,
        inplace = True)
values = dataset.values

# %%
date_index = dataset.index

# %%
data_clean = dataset.copy()
data_clean_ext = dataset.copy()
data_clean_ext['new_cases_predictions'] = data_clean_ext['new_cases_smoothed']
data_clean
# Out:
#             new_cases_smoothed  reproduction_rate  \
# date
# 2020-01-22               0.000               0.00
# 2020-01-23               0.000               0.00
# 2020-01-24               0.000               0.00
# 2020-01-25               0.000               0.00
# 2020-01-26               0.000               0.00
# ...                        ...                ...
# 2022-03-08           38934.286               0.65
# 2022-03-09           36641.429               0.66
# 2022-03-10           36330.429               0.69
# 2022-03-11           36104.714               0.71
# 2022-03-12           35464.143               0.71
#
#             new_tests_smoothed_per_thousand  \
# date
# 2020-01-22                            0.000
# 2020-01-23                            0.000
# 2020-01-24                            0.000
# 2020-01-25                            0.000
# 2020-01-26                            0.000
# ...                                     ...
# 2022-03-08                            2.748
# 2022-03-09                            2.699
# 2022-03-10                            2.613
# 2022-03-11                            2.580
# 2022-03-12                            2.561
#
#             new_vaccinations_smoothed_per_million  \
# date
# 2020-01-22                                      0
# 2020-01-23                                      0
# 2020-01-24                                      0
# 2020-01-25                                      0
# 2020-01-26                                      0
# ...                                           ...
# 2022-03-08                                    621
# 2022-03-09                                    601
# 2022-03-10                                    583
# 2022-03-11                                    557
# 2022-03-12                                    540
#
#             people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# date
# 2020-01-22                                 0.00                        0.00
# 2020-01-23                                 0.00                        0.00
# 2020-01-24                                 0.00                        0.00
# 2020-01-25                                 0.00                        0.00
# 2020-01-26                                 0.00                        0.00
# ...                                         ...                         ...
# 2022-03-08                                65.24                       28.89
# 2022-03-09                                65.25                       28.91
# 2022-03-10                                65.27                       28.94
# 2022-03-11                                65.29                       28.97
# 2022-03-12                                65.30                       28.99
#
#             stringency_index
# date
# 2020-01-22              0.00
# 2020-01-23              0.00
# 2020-01-24              0.00
# 2020-01-25              0.00
# 2020-01-26              0.00
# ...                      ...
# 2022-03-08             53.24
# 2022-03-09             53.24
# 2022-03-10             53.24
# 2022-03-11             53.24
# 2022-03-12             53.24
#
# [781 rows x 7 columns]

# %%
# number of rows in the data
nrows = data_clean.shape[0]

# %%
# Convert the data to numpy values
np_data_unscaled = np.array(data_clean)
np_data = np.reshape(np_data_unscaled, (nrows, -1))

# %%
# ensure all data is float
values = values.astype('float64')

# %%
# Transform the data by scaling each feature to a range between 0 and 1
scaler = MinMaxScaler()
np_data_scaled = scaler.fit_transform(np_data_unscaled)

# %%
# Creating a separate scaler that works on a single column for scaling predictions
scaler_pred = MinMaxScaler()
df_cases = pd.DataFrame(data_clean_ext['new_cases_smoothed'])
np_cases_scaled = scaler_pred.fit_transform(df_cases)

# %%
# Set the sequence length - this is the timeframe used to make a single prediction
sequence_length = 31

# Prediction Index
index_cases = dataset.columns.get_loc("new_cases_smoothed")

# Split the training data into train and train data sets
# As a first step, we get the number of rows to train the model on 80% of the data 
train_data_len = math.ceil(np_data_scaled.shape[0] * 0.8)

# Create the training and test data
train_data = np_data_scaled[0:train_data_len, :]
test_data = np_data_scaled[train_data_len - sequence_length:, :]

# The RNN needs data with the format of [samples, time steps, features]
# Here, we create N samples, sequence_length time steps per sample, and 6 features
def partition_dataset(sequence_length, data):
    x, y = [], []
    data_len = data.shape[0]
    for i in range(sequence_length, data_len):
        x.append(data[i-sequence_length:i,:]) #contains sequence_length values 0-sequence_length * columsn
        y.append(data[i, index_cases]) #contains the prediction values for validation,  for single-step prediction
    
    # Convert the x and y to numpy arrays
    x = np.array(x)
    y = np.array(y)
    return x, y

# Generate training data and test data
x_train, y_train = partition_dataset(sequence_length, train_data)
x_test, y_test = partition_dataset(sequence_length, test_data)

# Print the shapes: the result is: (rows, training_sequence, features) (prediction value, )
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)

# Validate that the prediction value and the input match up
# The last close price of the second input sample should equal the first prediction value
print(x_train[1][sequence_length-1][index_cases])
print(y_train[0])
# Out:
# (594, 31, 7) (594,)
# (156, 31, 7) (156,)
# 3.5412813093255167e-07
# 3.5412813093255167e-07

# %%
# Configure the neural network model
model = Sequential()
# Model with n_neurons = inputshape Timestamps, each with x_train.shape[2] variables
n_neurons = x_train.shape[1] * x_train.shape[2]
model.add(LSTM(n_neurons, return_sequences=False, input_shape=(x_train.shape[1], x_train.shape[2])))
#model.add(Dropout(0.2))
#model.add(LSTM(n_neurons, return_sequences=True))
#model.add(Dropout(0.2))
#model.add(LSTM(n_neurons, return_sequences=False))
#model.add(Dropout(0.2))
model.add(Dense(1))

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Compiling the LSTM
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
checkpoint_path = 'my_best_model.hdf5'
checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

earlystopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True, verbose =1)
callbacks = [checkpoint, earlystopping]

# %%
# Training the model
epochs = 300
batch_size = 20
early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)
history = model.fit(x_train, y_train,
                     batch_size=batch_size, 
                     epochs=epochs,
                     validation_data=(x_test, y_test),
                     callbacks = callbacks)
# Out:
# Epoch 1/300
# 30/30 [==============================] - 1s 39ms/step - loss: 1.0991e-05 - val_loss: 0.0028
#
# Epoch 00001: val_loss improved from inf to 0.00277, saving model to my_best_model.hdf5
# Epoch 2/300
# 30/30 [==============================] - 1s 39ms/step - loss: 8.3958e-06 - val_loss: 0.0035
#
# Epoch 00002: val_loss did not improve from 0.00277
# Epoch 3/300
# 30/30 [==============================] - 1s 41ms/step - loss: 7.2402e-06 - val_loss: 0.0027
#
# Epoch 00003: val_loss improved from 0.00277 to 0.00268, saving model to my_best_model.hdf5
# Epoch 4/300
# 30/30 [==============================] - 1s 40ms/step - loss: 8.8049e-06 - val_loss: 0.0038
#
# Epoch 00004: val_loss did not improve from 0.00268
# Epoch 5/300
# 30/30 [==============================] - 1s 41ms/step - loss: 9.7016e-06 - val_loss: 0.0030
#
# Epoch 00005: val_loss did not improve from 0.00268
# Epoch 6/300
# 30/30 [==============================] - 1s 39ms/step - loss: 6.2429e-06 - val_loss: 0.0032
#
# Epoch 00006: val_loss did not improve from 0.00268
# Epoch 7/300
# 30/30 [==============================] - 1s 41ms/step - loss: 6.1859e-06 - val_loss: 0.0033
#
# Epoch 00007: val_loss did not improve from 0.00268
# Epoch 8/300
# 30/30 [==============================] - 1s 39ms/step - loss: 9.1756e-06 - val_loss: 0.0045
#
# Epoch 00008: val_loss did not improve from 0.00268
# Epoch 9/300
# 30/30 [==============================] - 1s 40ms/step - loss: 9.5828e-06 - val_loss: 0.0028
#
# Epoch 00009: val_loss did not improve from 0.00268
# Epoch 10/300
# 30/30 [==============================] - 1s 48ms/step - loss: 7.8171e-06 - val_loss: 0.0034
#
# Epoch 00010: val_loss did not improve from 0.00268
# Epoch 11/300
# 30/30 [==============================] - 1s 41ms/step - loss: 1.2238e-05 - val_loss: 0.0026
#
# Epoch 00011: val_loss improved from 0.00268 to 0.00264, saving model to my_best_model.hdf5
# Epoch 12/300
# 30/30 [==============================] - 1s 41ms/step - loss: 8.3109e-06 - val_loss: 0.0038
#
# Epoch 00012: val_loss did not improve from 0.00264
# Epoch 13/300
# 30/30 [==============================] - 1s 42ms/step - loss: 1.1375e-05 - val_loss: 0.0028
#
# Epoch 00013: val_loss did not improve from 0.00264
# Epoch 14/300
# 30/30 [==============================] - 1s 42ms/step - loss: 9.1366e-06 - val_loss: 0.0037
#
# Epoch 00014: val_loss did not improve from 0.00264
# Epoch 15/300
# 30/30 [==============================] - 1s 42ms/step - loss: 7.8855e-06 - val_loss: 0.0034
#
# Epoch 00015: val_loss did not improve from 0.00264
# Epoch 16/300
# 30/30 [==============================] - 1s 43ms/step - loss: 8.4165e-06 - val_loss: 0.0028
#
# Epoch 00016: val_loss did not improve from 0.00264
# Epoch 17/300
# 30/30 [==============================] - 1s 40ms/step - loss: 8.7533e-06 - val_loss: 0.0038
#
# Epoch 00017: val_loss did not improve from 0.00264
# Epoch 18/300
# 30/30 [==============================] - 1s 41ms/step - loss: 6.7560e-06 - val_loss: 0.0041
#
# Epoch 00018: val_loss did not improve from 0.00264
# Epoch 19/300
# 30/30 [==============================] - 1s 41ms/step - loss: 7.9691e-06 - val_loss: 0.0035
#
# Epoch 00019: val_loss did not improve from 0.00264
# Epoch 20/300
# 30/30 [==============================] - 1s 44ms/step - loss: 8.6658e-06 - val_loss: 0.0028
#
# Epoch 00020: val_loss did not improve from 0.00264
# Epoch 21/300
# 30/30 [==============================] - 1s 49ms/step - loss: 1.1931e-05 - val_loss: 0.0040
#
# Epoch 00021: val_loss did not improve from 0.00264
# Epoch 22/300
# 30/30 [==============================] - 1s 43ms/step - loss: 8.1770e-06 - val_loss: 0.0054
#
# Epoch 00022: val_loss did not improve from 0.00264
# Epoch 23/300
# 30/30 [==============================] - 1s 43ms/step - loss: 9.0176e-06 - val_loss: 0.0034
#
# Epoch 00023: val_loss did not improve from 0.00264
# Epoch 24/300
# 30/30 [==============================] - 1s 44ms/step - loss: 6.1746e-06 - val_loss: 0.0031
#
# Epoch 00024: val_loss did not improve from 0.00264
# Epoch 25/300
# 30/30 [==============================] - 1s 40ms/step - loss: 1.0213e-05 - val_loss: 0.0043
#
# Epoch 00025: val_loss did not improve from 0.00264
# Epoch 26/300
# 30/30 [==============================] - 1s 41ms/step - loss: 1.1192e-05 - val_loss: 0.0043
#
# Epoch 00026: val_loss did not improve from 0.00264
# Epoch 27/300
# 30/30 [==============================] - 1s 48ms/step - loss: 8.8174e-06 - val_loss: 0.0038
#
# Epoch 00027: val_loss did not improve from 0.00264
# Epoch 28/300
# 30/30 [==============================] - 1s 44ms/step - loss: 8.9521e-06 - val_loss: 0.0033
#
# Epoch 00028: val_loss did not improve from 0.00264
# Epoch 29/300
# 30/30 [==============================] - 1s 46ms/step - loss: 1.1806e-05 - val_loss: 0.0038
#
# Epoch 00029: val_loss did not improve from 0.00264
# Epoch 30/300
# 30/30 [==============================] - 2s 56ms/step - loss: 7.9730e-06 - val_loss: 0.0040
#
# Epoch 00030: val_loss did not improve from 0.00264
# Epoch 31/300
# 30/30 [==============================] - 1s 46ms/step - loss: 8.6012e-06 - val_loss: 0.0031
#
# Epoch 00031: val_loss did not improve from 0.00264
# Epoch 32/300
# 30/30 [==============================] - 2s 58ms/step - loss: 1.0249e-05 - val_loss: 0.0040
#
# Epoch 00032: val_loss did not improve from 0.00264
# Epoch 33/300
# 30/30 [==============================] - 2s 62ms/step - loss: 7.6798e-06 - val_loss: 0.0038
#
# Epoch 00033: val_loss did not improve from 0.00264
# Epoch 34/300
# 30/30 [==============================] - 2s 57ms/step - loss: 1.5797e-05 - val_loss: 0.0039
#
# Epoch 00034: val_loss did not improve from 0.00264
# Epoch 35/300
# 30/30 [==============================] - 3s 86ms/step - loss: 9.1594e-06 - val_loss: 0.0055
#
# Epoch 00035: val_loss did not improve from 0.00264
# Epoch 36/300
# 30/30 [==============================] - 2s 80ms/step - loss: 8.7086e-06 - val_loss: 0.0048
#
# Epoch 00036: val_loss did not improve from 0.00264
# Epoch 37/300
# 30/30 [==============================] - 3s 86ms/step - loss: 8.2211e-06 - val_loss: 0.0032
#
# Epoch 00037: val_loss did not improve from 0.00264
# Epoch 38/300
# 30/30 [==============================] - 2s 83ms/step - loss: 1.1790e-05 - val_loss: 0.0044
#
# Epoch 00038: val_loss did not improve from 0.00264
# Epoch 39/300
# 30/30 [==============================] - 3s 87ms/step - loss: 7.2188e-06 - val_loss: 0.0032
#
# Epoch 00039: val_loss did not improve from 0.00264
# Epoch 40/300
# 30/30 [==============================] - 3s 85ms/step - loss: 8.2813e-06 - val_loss: 0.0034
#
# Epoch 00040: val_loss did not improve from 0.00264
# Epoch 41/300
# 30/30 [==============================] - 3s 89ms/step - loss: 8.3493e-06 - val_loss: 0.0045
#
# Epoch 00041: val_loss did not improve from 0.00264
# Epoch 42/300
# 30/30 [==============================] - 2s 65ms/step - loss: 9.6761e-06 - val_loss: 0.0044
#
# Epoch 00042: val_loss did not improve from 0.00264
# Epoch 43/300
# 30/30 [==============================] - 2s 71ms/step - loss: 8.5839e-06 - val_loss: 0.0039
#
# Epoch 00043: val_loss did not improve from 0.00264
# Epoch 44/300
# 30/30 [==============================] - 2s 64ms/step - loss: 8.0587e-06 - val_loss: 0.0038
#
# Epoch 00044: val_loss did not improve from 0.00264
# Epoch 45/300
# 30/30 [==============================] - 2s 63ms/step - loss: 7.3546e-06 - val_loss: 0.0042
#
# Epoch 00045: val_loss did not improve from 0.00264
# Epoch 46/300
# 30/30 [==============================] - 2s 59ms/step - loss: 1.0121e-05 - val_loss: 0.0046
#
# Epoch 00046: val_loss did not improve from 0.00264
# Epoch 47/300
# 30/30 [==============================] - 2s 55ms/step - loss: 1.5024e-05 - val_loss: 0.0041
#
# Epoch 00047: val_loss did not improve from 0.00264
# Epoch 48/300
# 30/30 [==============================] - 2s 70ms/step - loss: 8.7581e-06 - val_loss: 0.0032
#
# Epoch 00048: val_loss did not improve from 0.00264
# Epoch 49/300
# 30/30 [==============================] - 2s 69ms/step - loss: 6.8357e-06 - val_loss: 0.0042
#
# Epoch 00049: val_loss did not improve from 0.00264
# Epoch 50/300
# 30/30 [==============================] - 2s 82ms/step - loss: 7.8380e-06 - val_loss: 0.0037
#
# Epoch 00050: val_loss did not improve from 0.00264
# Epoch 51/300
# 30/30 [==============================] - 1s 37ms/step - loss: 6.4888e-06 - val_loss: 0.0035
#
# Epoch 00051: val_loss did not improve from 0.00264
# Epoch 52/300
# 30/30 [==============================] - 1s 42ms/step - loss: 1.0188e-05 - val_loss: 0.0023
#
# Epoch 00052: val_loss improved from 0.00264 to 0.00229, saving model to my_best_model.hdf5
# Epoch 53/300
# 30/30 [==============================] - 1s 39ms/step - loss: 8.3576e-06 - val_loss: 0.0037
#
# Epoch 00053: val_loss did not improve from 0.00229
# Epoch 54/300
# 30/30 [==============================] - 1s 42ms/step - loss: 6.2923e-06 - val_loss: 0.0030
#
# Epoch 00054: val_loss did not improve from 0.00229
# Epoch 55/300
# 30/30 [==============================] - 1s 38ms/step - loss: 1.3385e-05 - val_loss: 0.0053
#
# Epoch 00055: val_loss did not improve from 0.00229
# Epoch 56/300
# 30/30 [==============================] - 1s 41ms/step - loss: 1.1221e-05 - val_loss: 0.0052
#
# Epoch 00056: val_loss did not improve from 0.00229
# Epoch 57/300
# 30/30 [==============================] - 1s 37ms/step - loss: 8.2993e-06 - val_loss: 0.0040
#
# Epoch 00057: val_loss did not improve from 0.00229
# Epoch 58/300
# 30/30 [==============================] - 1s 42ms/step - loss: 7.5815e-06 - val_loss: 0.0040
#
# Epoch 00058: val_loss did not improve from 0.00229
# Epoch 59/300
# 30/30 [==============================] - 1s 40ms/step - loss: 1.6032e-05 - val_loss: 0.0026
#
# Epoch 00059: val_loss did not improve from 0.00229
# Epoch 60/300
# 30/30 [==============================] - 1s 39ms/step - loss: 7.5711e-06 - val_loss: 0.0031
#
# Epoch 00060: val_loss did not improve from 0.00229
# Epoch 61/300
# 30/30 [==============================] - 1s 45ms/step - loss: 8.7941e-06 - val_loss: 0.0030
#
# Epoch 00061: val_loss did not improve from 0.00229
# Epoch 62/300
# 30/30 [==============================] - 1s 40ms/step - loss: 6.1092e-06 - val_loss: 0.0032
#
# Epoch 00062: val_loss did not improve from 0.00229
# Epoch 63/300
# 30/30 [==============================] - 2s 52ms/step - loss: 7.3950e-06 - val_loss: 0.0039
#
# Epoch 00063: val_loss did not improve from 0.00229
# Epoch 64/300
# 30/30 [==============================] - 1s 44ms/step - loss: 7.8326e-06 - val_loss: 0.0037
#
# Epoch 00064: val_loss did not improve from 0.00229
# Epoch 65/300
# 30/30 [==============================] - 1s 39ms/step - loss: 1.0270e-05 - val_loss: 0.0053
#
# Epoch 00065: val_loss did not improve from 0.00229
# Epoch 66/300
# 30/30 [==============================] - 1s 35ms/step - loss: 6.6766e-06 - val_loss: 0.0040
#
# Epoch 00066: val_loss did not improve from 0.00229
# Epoch 67/300
# 30/30 [==============================] - 1s 36ms/step - loss: 5.9906e-06 - val_loss: 0.0029
#
# Epoch 00067: val_loss did not improve from 0.00229
# Epoch 68/300
# 30/30 [==============================] - 1s 36ms/step - loss: 5.8414e-06 - val_loss: 0.0042
#
# Epoch 00068: val_loss did not improve from 0.00229
# Epoch 69/300
# 30/30 [==============================] - 1s 35ms/step - loss: 7.7380e-06 - val_loss: 0.0042
#
# Epoch 00069: val_loss did not improve from 0.00229
# Epoch 70/300
# 30/30 [==============================] - 1s 38ms/step - loss: 8.3369e-06 - val_loss: 0.0049
#
# Epoch 00070: val_loss did not improve from 0.00229
# Epoch 71/300
# 30/30 [==============================] - 1s 40ms/step - loss: 9.2020e-06 - val_loss: 0.0033
#
# Epoch 00071: val_loss did not improve from 0.00229
# Epoch 72/300
# 30/30 [==============================] - 1s 42ms/step - loss: 7.0123e-06 - val_loss: 0.0030
#
# Epoch 00072: val_loss did not improve from 0.00229
# Epoch 73/300
# 30/30 [==============================] - 1s 43ms/step - loss: 7.7490e-06 - val_loss: 0.0037
#
# Epoch 00073: val_loss did not improve from 0.00229
# Epoch 74/300
# 30/30 [==============================] - 1s 43ms/step - loss: 7.4316e-06 - val_loss: 0.0033
#
# Epoch 00074: val_loss did not improve from 0.00229
# Epoch 75/300
# 30/30 [==============================] - 2s 53ms/step - loss: 8.4449e-06 - val_loss: 0.0038
#
# Epoch 00075: val_loss did not improve from 0.00229
# Epoch 76/300
# 30/30 [==============================] - 1s 45ms/step - loss: 8.0267e-06 - val_loss: 0.0033
#
# Epoch 00076: val_loss did not improve from 0.00229
# Epoch 77/300
# 30/30 [==============================] - 1s 49ms/step - loss: 7.5878e-06 - val_loss: 0.0042
#
# Epoch 00077: val_loss did not improve from 0.00229
# Epoch 78/300
# 30/30 [==============================] - 1s 49ms/step - loss: 6.9715e-06 - val_loss: 0.0041
#
# Epoch 00078: val_loss did not improve from 0.00229
# Epoch 79/300
# 30/30 [==============================] - 2s 55ms/step - loss: 7.1291e-06 - val_loss: 0.0034
#
# Epoch 00079: val_loss did not improve from 0.00229
# Epoch 80/300
# 30/30 [==============================] - 2s 52ms/step - loss: 6.4670e-06 - val_loss: 0.0036
#
# Epoch 00080: val_loss did not improve from 0.00229
# Epoch 81/300
# 30/30 [==============================] - 2s 64ms/step - loss: 8.1542e-06 - val_loss: 0.0051
#
# Epoch 00081: val_loss did not improve from 0.00229
# Epoch 82/300
# 30/30 [==============================] - 2s 58ms/step - loss: 7.5781e-06 - val_loss: 0.0044
#
# Epoch 00082: val_loss did not improve from 0.00229
# Epoch 83/300
# 30/30 [==============================] - 2s 56ms/step - loss: 7.6679e-06 - val_loss: 0.0044
#
# Epoch 00083: val_loss did not improve from 0.00229
# Epoch 84/300
# 30/30 [==============================] - 1s 44ms/step - loss: 8.9839e-06 - val_loss: 0.0035
#
# Epoch 00084: val_loss did not improve from 0.00229
# Epoch 85/300
# 30/30 [==============================] - 1s 47ms/step - loss: 6.0546e-06 - val_loss: 0.0041
#
# Epoch 00085: val_loss did not improve from 0.00229
# Epoch 86/300
# 30/30 [==============================] - 1s 43ms/step - loss: 1.2514e-05 - val_loss: 0.0034
#
# Epoch 00086: val_loss did not improve from 0.00229
# Epoch 87/300
# 30/30 [==============================] - 1s 45ms/step - loss: 1.0075e-05 - val_loss: 0.0042
#
# Epoch 00087: val_loss did not improve from 0.00229
# Epoch 88/300
# 30/30 [==============================] - 1s 39ms/step - loss: 6.6957e-06 - val_loss: 0.0041
#
# Epoch 00088: val_loss did not improve from 0.00229
# Epoch 89/300
# 30/30 [==============================] - 1s 41ms/step - loss: 6.5937e-06 - val_loss: 0.0032
#
# Epoch 00089: val_loss did not improve from 0.00229
# Epoch 90/300
# 30/30 [==============================] - 1s 39ms/step - loss: 8.4702e-06 - val_loss: 0.0038
#
# Epoch 00090: val_loss did not improve from 0.00229
# Epoch 91/300
# 30/30 [==============================] - 1s 40ms/step - loss: 7.3398e-06 - val_loss: 0.0041
#
# Epoch 00091: val_loss did not improve from 0.00229
# Epoch 92/300
# 30/30 [==============================] - 1s 40ms/step - loss: 8.0427e-06 - val_loss: 0.0044
#
# Epoch 00092: val_loss did not improve from 0.00229
# Epoch 93/300
# 30/30 [==============================] - 1s 44ms/step - loss: 9.7241e-06 - val_loss: 0.0036
#
# Epoch 00093: val_loss did not improve from 0.00229
# Epoch 94/300
# 30/30 [==============================] - 1s 45ms/step - loss: 6.5063e-06 - val_loss: 0.0039
#
# Epoch 00094: val_loss did not improve from 0.00229
# Epoch 95/300
# 30/30 [==============================] - 1s 49ms/step - loss: 7.9684e-06 - val_loss: 0.0045
#
# Epoch 00095: val_loss did not improve from 0.00229
# Epoch 96/300
# 30/30 [==============================] - 1s 41ms/step - loss: 7.4064e-06 - val_loss: 0.0042
#
# Epoch 00096: val_loss did not improve from 0.00229
# Epoch 97/300
# 30/30 [==============================] - 1s 39ms/step - loss: 7.4048e-06 - val_loss: 0.0048
#
# Epoch 00097: val_loss did not improve from 0.00229
# Epoch 98/300
# 30/30 [==============================] - 1s 42ms/step - loss: 8.0526e-06 - val_loss: 0.0031
#
# Epoch 00098: val_loss did not improve from 0.00229
# Epoch 99/300
# 30/30 [==============================] - 1s 39ms/step - loss: 9.0255e-06 - val_loss: 0.0044
#
# Epoch 00099: val_loss did not improve from 0.00229
# Epoch 100/300
# 30/30 [==============================] - 1s 41ms/step - loss: 6.4762e-06 - val_loss: 0.0045
#
# Epoch 00100: val_loss did not improve from 0.00229
# Epoch 101/300
# 30/30 [==============================] - 1s 39ms/step - loss: 7.4923e-06 - val_loss: 0.0051
#
# Epoch 00101: val_loss did not improve from 0.00229
# Epoch 102/300
# 30/30 [==============================] - 1s 40ms/step - loss: 9.8017e-06 - val_loss: 0.0033
#
# Epoch 00102: val_loss did not improve from 0.00229
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping

# %%
from tensorflow.keras.models import load_model
model_from_saved_checkpoint = load_model(checkpoint_path)

# %%
# Plot training & validation loss values
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# Get the predicted values
y_pred_scaled = model_from_saved_checkpoint.predict(x_test)

# %%
# Unscale the predicted values
y_pred = scaler_pred.inverse_transform(y_pred_scaled)

# %%
y_test_unscaled = scaler_pred.inverse_transform(y_test.reshape(-1, 1))

# %%
# Mean Absolute Error (MAE)
MAE = mean_absolute_error(y_test_unscaled, y_pred)
print(f'Median Absolute Error (MAE): {np.round(MAE, 2)}')

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print(f'Mean Absolute Percentage Error (MAPE): {np.round(MAPE, 2)} %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled)) ) * 100
print(f'Median Absolute Percentage Error (MDAPE): {np.round(MDAPE, 2)} %')
# Out:
# Median Absolute Error (MAE): 22982.68
# Mean Absolute Percentage Error (MAPE): 9.07 %
# Median Absolute Percentage Error (MDAPE): 8.98 %

# %%
plt.plot(y_test_unscaled, label='True')
plt.plot(y_pred, label='LSTM')
plt.title("LSTM's_Prediction")
plt.xlabel('Observation')
plt.ylabel('Cases Prediction')
plt.legend()
plt.show()

# %%
new_df = data_clean[-sequence_length:]
N = sequence_length

# %%
# Get the last N day closing price values and scale the data to be values between 0 and 1
last_N_days = new_df[-sequence_length:].values
last_N_days_scaled = scaler.transform(last_N_days)

# %%
# Create an empty list and Append past N days
X_test_new = []
X_test_new.append(last_N_days_scaled)

# Convert the X_test data set to a numpy array and reshape the data
pred_cases_scaled = model_from_saved_checkpoint.predict(np.array(X_test_new))
pred_cases_unscaled = scaler_pred.inverse_transform(pred_cases_scaled.reshape(-1, 1))

# %%
# Print last price and predicted price for the next day
cases_today = np.round(new_df['new_cases_smoothed'][-1], 2)
predicted_cases = np.round(pred_cases_unscaled.ravel()[0], 2)
change_percent = np.round(100 - (price_today * 100)/predicted_price, 2)

# %%
plus = '+'; minus = ''
print(f'The close covid cases count today is  {cases_today}')
print(f'The predicted case count for the next day is {predicted_cases} ({plus if change_percent > 0 else minus}{change_percent}%)')
# Out:
# The close covid cases count today is  35464.14
# The predicted case count for the next day is 26273.419921875 (-135.22%)

# %%
# !jupyter nbconvert covid_analysis.ipynb --to markdown --NbConvertApp.output_files_dir=.
